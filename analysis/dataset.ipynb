# %%
data_path = '../data/'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.io.arff import loadarff

# %matplotlib inline

# %% [markdown]
# ### TOC
# - [Year 1](#Year-1)
# - [Year 2](#Year-2)
# - [Year 3](#Year-3)
# - [Year 4](#Year-4)
# - [Year 5](#Year-5)

# %% [markdown]
# ---
# ## Year 1

# %%
arff = loadarff(data_path+'1year.arff')
df = pd.DataFrame(arff[0])

# %%
df['class']= df['class'].astype('int')
df.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7    Attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     Attr9   Attr10  ...    Attr56   Attr57   Attr58    Attr59  Attr60  Attr61  \
# 0  1.1389  0.50494  ...  0.121960  0.39718  0.87804  0.001924  8.4160  5.1372
# 1  1.6996  0.49788  ...  0.121300  0.42002  0.85300  0.000000  4.1486  3.2732
# 2  1.3090  0.30408  ...  0.241140  0.81774  0.76599  0.694840  4.9909  3.9510
# 3  1.0571  0.57353  ...  0.054015  0.14207  0.94598  0.000000  4.5746  3.6147
# 4  1.1559  0.38677  ...  0.134850  0.48431  0.86515  0.124440  6.3985  4.3158
#
#     Attr62  Attr63   Attr64  class
# ...

# %%
df['class'].value_counts()
# Out:
# 0    6756
# 1     271
# Name: class, dtype: int64

# %%
df_pos = df[df['class']==1]
df_neg = df[df['class']==0]

# %%
percent_missing = df_pos.isnull().sum()
percent_missing_p = percent_missing / df_pos.shape[0] * 100.00
missing_value_df = pd.DataFrame({'column_name': df_pos.columns,
                                 'num_missing': percent_missing,
                                 'percent_missing': percent_missing_p})
missing_value_df.sort_values('percent_missing', inplace=True, ascending=False)
missing_value_df[:10]
# Out:
#        column_name  num_missing  percent_missing
# Attr27      Attr27          120        44.280443
# Attr21      Attr21          109        40.221402
# Attr37      Attr37          105        38.745387
# Attr11      Attr11           36        13.284133
# Attr60      Attr60           14         5.166052
# Attr45      Attr45           14         5.166052
# Attr28      Attr28            6         2.214022
# Attr64      Attr64            6         2.214022
# Attr54      Attr54            6         2.214022
# Attr53      Attr53            6         2.214022

# %%
percent_missing = df_neg.isnull().sum()
percent_missing_p = percent_missing / df_neg.shape[0] * 100.00
missing_value_df = pd.DataFrame({'column_name': df_neg.columns,
                                 'num_missing': percent_missing,
                                 'percent_missing': percent_missing_p})
missing_value_df.sort_values('percent_missing', inplace=True, ascending=False)
missing_value_df[:10]
# Out:
#        column_name  num_missing  percent_missing
# Attr37      Attr37         2635        39.002368
# Attr21      Attr21         1513        22.394908
# Attr27      Attr27          191         2.827117
# Attr24      Attr24          124         1.835406
# Attr60      Attr60          121         1.791001
# Attr45      Attr45          120         1.776199
# Attr41      Attr41           84         1.243339
# Attr32      Attr32           37         0.547661
# Attr12      Attr12           30         0.444050
# Attr46      Attr46           30         0.444050

# %%
percent_missing = df.isnull().sum()
percent_missing_p = percent_missing / df.shape[0] * 100.00
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'num_missing': percent_missing,
                                 'percent_missing': percent_missing_p})
missing_value_df.sort_values('percent_missing', inplace=True, ascending=False)
missing_value_df[:10]
# Out:
#        column_name  num_missing  percent_missing
# Attr37      Attr37         2740        38.992458
# Attr21      Attr21         1622        23.082396
# Attr27      Attr27          311         4.425786
# Attr60      Attr60          135         1.921161
# Attr45      Attr45          134         1.906930
# Attr24      Attr24          124         1.764622
# Attr41      Attr41           84         1.195389
# Attr11      Attr11           39         0.555002
# Attr32      Attr32           38         0.540771
# Attr28      Attr28           34         0.483848

# %%
with pd.option_context('display.max_columns', None):
    display(df_pos.describe())
    display(df_neg.describe())
    display(df.describe())
# Out:
#             Attr1       Attr2       Attr3       Attr4          Attr5  \
# count  271.000000  271.000000  271.000000  271.000000     271.000000
# mean    -0.207890    2.300058   -1.594335    3.162163    -635.598537
# std      3.748644   26.781277   26.763333   17.276740    9910.324721
# min    -61.602000    0.003824 -440.500000    0.002265 -163090.000000
# 25%     -0.011543    0.466480   -0.086121    0.838025     -68.358000
# 50%      0.020529    0.648240    0.046512    1.096800     -34.248000
# 75%      0.090589    0.807275    0.219850    1.565950      -1.388100
# max      1.138800  441.500000    0.996180  261.500000    4810.700000
#
#             Attr6       Attr7       Attr8       Attr9      Attr10      Attr11  \
# count  271.000000  271.000000  271.000000  271.000000  271.000000  235.000000
# mean    -1.520304   -0.193426    2.609932    1.957614   -1.334031    0.062843
# std     24.169616    3.750413   17.012848    3.160104   26.782555    0.187202
# ...

# %% [markdown]
# ---
# ## Year 2

# %%
arff = loadarff(data_path+'2year.arff')
df = pd.DataFrame(arff[0])

# %%
df['class']= df['class'].astype('int')
df.head()
# Out:
#       Attr1    Attr2     Attr3   Attr4   Attr5     Attr6    Attr7    Attr8  \
# 0  0.202350  0.46500  0.240380  1.5171 -14.547  0.510690  0.25366  0.91816
# 1  0.030073  0.59563  0.186680  1.3382 -37.859 -0.000319  0.04167  0.67890
# 2  0.257860  0.29949  0.665190  3.2211  71.799  0.000000  0.31877  2.33200
# 3  0.227160  0.67850  0.042784  1.0828 -88.212  0.000000  0.28505  0.47384
# 4  0.085443  0.38039  0.359230  1.9444  21.731  0.187900  0.10823  1.37140
#
#      Attr9   Attr10  ...   Attr56    Attr57   Attr58   Attr59  Attr60  \
# 0  1.15190  0.42695  ...  0.13184  0.473950  0.86816  0.00024  8.5487
# 1  0.32356  0.40437  ...  0.12146  0.074369  0.87235  0.00000  1.5264
# 2  1.67620  0.69841  ...  0.16499  0.369210  0.81614  0.00000  4.3325
# 3  1.32410  0.32150  ...  0.29358  0.706570  0.78617  0.48456  5.2309
# 4  1.11260  0.52167  ...  0.10124  0.163790  0.89876  0.00000  5.7035
#
#     Attr61   Attr62   Attr63   Attr64  class
# 0  5.16550  107.740  3.38790   5.3440      0
# ...

# %%
df['class'].value_counts()
# Out:
# 0    9773
# 1     400
# Name: class, dtype: int64

# %%
df_pos = df[df['class']==1]
df_neg = df[df['class']==0]

# %%
percent_missing = df_pos.isnull().sum()
percent_missing_p = percent_missing / df_pos.shape[0] * 100.00
missing_value_df = pd.DataFrame({'column_name': df_pos.columns,
                                 'num_missing': percent_missing,
                                 'percent_missing': percent_missing_p})
missing_value_df.sort_values('percent_missing', inplace=True, ascending=False)
missing_value_df[:10]
# Out:
#        column_name  num_missing  percent_missing
# Attr37      Attr37          178            44.50
# Attr21      Attr21          154            38.50
# Attr27      Attr27          151            37.75
# Attr45      Attr45           29             7.25
# Attr60      Attr60           29             7.25
# Attr28      Attr28           13             3.25
# Attr64      Attr64           13             3.25
# Attr54      Attr54           13             3.25
# Attr53      Attr53           13             3.25
# Attr23      Attr23            5             1.25

# %%
percent_missing = df_neg.isnull().sum()
percent_missing_p = percent_missing / df_neg.shape[0] * 100.00
missing_value_df = pd.DataFrame({'column_name': df_neg.columns,
                                 'num_missing': percent_missing,
                                 'percent_missing': percent_missing_p})
missing_value_df.sort_values('percent_missing', inplace=True, ascending=False)
missing_value_df[:10]
# Out:
#        column_name  num_missing  percent_missing
# Attr37      Attr37         4340        44.408063
# Attr21      Attr21         3010        30.799140
# Attr27      Attr27          555         5.678911
# Attr60      Attr60          514         5.259388
# Attr45      Attr45          512         5.238924
# Attr24      Attr24          225         2.302261
# Attr53      Attr53          199         2.036222
# Attr64      Attr64          199         2.036222
# Attr28      Attr28          199         2.036222
# Attr54      Attr54          199         2.036222

# %%
percent_missing = df.isnull().sum()
percent_missing_p = percent_missing / df.shape[0] * 100.00
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'num_missing': percent_missing,
                                 'percent_missing': percent_missing_p})
missing_value_df.sort_values('percent_missing', inplace=True, ascending=False)
missing_value_df[:10]
# Out:
#        column_name  num_missing  percent_missing
# Attr37      Attr37         4518        44.411678
# Attr21      Attr21         3164        31.101936
# Attr27      Attr27          706         6.939939
# Attr60      Attr60          543         5.337659
# Attr45      Attr45          541         5.317999
# Attr24      Attr24          225         2.211737
# Attr53      Attr53          212         2.083948
# Attr64      Attr64          212         2.083948
# Attr28      Attr28          212         2.083948
# Attr54      Attr54          212         2.083948

# %%
with pd.option_context('display.max_columns', None):
    display(df_pos.describe())
    display(df_neg.describe())
    display(df.describe())
# Out:
#             Attr1       Attr2       Attr3       Attr4          Attr5  \
# count  400.000000  400.000000  400.000000  399.000000     400.000000
# mean    -0.022682    1.894548   -1.181474    3.667563    -437.077408
# std      0.656483   24.019438   24.004984   18.986811    7339.305097
# min     -6.815000    0.000000 -479.960000    0.002079 -146150.000000
# 25%     -0.044411    0.425833   -0.103102    0.821475     -76.126000
# 50%      0.012760    0.639390    0.057615    1.135400     -29.141000
# 75%      0.072398    0.827192    0.235972    1.732500       7.308525
# max      7.372700  480.960000    0.996880  320.420000    2614.700000
#
#             Attr6       Attr7        Attr8       Attr9      Attr10  \
# count  400.000000  400.000000   399.000000  400.000000  400.000000
# mean    -1.427632   -0.012300    12.379267    2.191538   -0.732845
# std     25.587490    0.660678   148.609046    5.768729   24.309616
# min   -508.410000   -6.815000    -0.997810    0.000000 -479.910000
# ...

# %% [markdown]
# ---
# ## Year 3

# %%
arff = loadarff(data_path+'3year.arff')
df = pd.DataFrame(arff[0])

# %%
df['class']= df['class'].astype('int')
df.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7   Attr8  \
# 0  0.174190  0.41299  0.14371  1.3480 -28.9820  0.60383  0.219460  1.1225
# 1  0.146240  0.46038  0.28230  1.6294   2.5952  0.00000  0.171850  1.1721
# 2  0.000595  0.22612  0.48839  3.1599  84.8740  0.19114  0.004572  2.9881
# 3  0.024526  0.43236  0.27546  1.7833 -10.1050  0.56944  0.024526  1.3057
# 4  0.188290  0.41504  0.34231  1.9279 -58.2740  0.00000  0.233580  1.4094
#
#     Attr9   Attr10  ...    Attr56    Attr57   Attr58    Attr59  Attr60  \
# 0  1.1961  0.46359  ...  0.163960  0.375740  0.83604  0.000007  9.7145
# 1  1.6018  0.53962  ...  0.027516  0.271000  0.90108  0.000000  5.9882
# 2  1.0077  0.67566  ...  0.007639  0.000881  0.99236  0.000000  6.7742
# 3  1.0509  0.56453  ...  0.048398  0.043445  0.95160  0.142980  4.2286
# 4  1.3393  0.58496  ...  0.176480  0.321880  0.82635  0.073039  2.5912
#
#    Attr61   Attr62  Attr63  Attr64  class
# 0  6.2813   84.291  4.3303  4.0341      0
# ...

# %%
df['class'].value_counts()
# Out:
# 0    10008
# 1      495
# Name: class, dtype: int64

# %%
df_pos = df[df['class']==1]
df_neg = df[df['class']==0]

# %%
percent_missing = df_pos.isnull().sum()
percent_missing_p = percent_missing / df_pos.shape[0] * 100.00
missing_value_df = pd.DataFrame({'column_name': df_pos.columns,
                                 'num_missing': percent_missing,
                                 'percent_missing': percent_missing_p})
missing_value_df.sort_values('percent_missing', inplace=True, ascending=False)
missing_value_df
# Out:
#        column_name  num_missing  percent_missing
# Attr37      Attr37          225        45.454545
# Attr27      Attr27          167        33.737374
# Attr21      Attr21          140        28.282828
# Attr45      Attr45           42         8.484848
# Attr60      Attr60           42         8.484848
# ...            ...          ...              ...
# Attr29      Attr29            0         0.000000
# Attr2        Attr2            0         0.000000
# Attr35      Attr35            0         0.000000
# Attr36      Attr36            0         0.000000
# class        class            0         0.000000
#
# [65 rows x 3 columns]

# %%
percent_missing = df_neg.isnull().sum()
percent_missing_p = percent_missing / df_neg.shape[0] * 100.00
missing_value_df = pd.DataFrame({'column_name': df_neg.columns,
                                 'num_missing': percent_missing,
                                 'percent_missing': percent_missing_p})
missing_value_df.sort_values('percent_missing', inplace=True, ascending=False)
missing_value_df
# Out:
#        column_name  num_missing  percent_missing
# Attr37      Attr37         4511        45.073941
# Attr21      Attr21          667         6.664668
# Attr60      Attr60          550         5.495604
# Attr45      Attr45          549         5.485612
# Attr27      Attr27          548         5.475620
# ...            ...          ...              ...
# Attr10      Attr10            0         0.000000
# Attr7        Attr7            0         0.000000
# Attr6        Attr6            0         0.000000
# Attr3        Attr3            0         0.000000
# class        class            0         0.000000
#
# [65 rows x 3 columns]

# %%
percent_missing = df.isnull().sum()
percent_missing_p = percent_missing / df.shape[0] * 100.00
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'num_missing': percent_missing,
                                 'percent_missing': percent_missing_p})
missing_value_df.sort_values('percent_missing', inplace=True, ascending=False)
missing_value_df
# Out:
#        column_name  num_missing  percent_missing
# Attr37      Attr37         4736        45.091879
# Attr21      Attr21          807         7.683519
# Attr27      Attr27          715         6.807579
# Attr60      Attr60          592         5.636485
# Attr45      Attr45          591         5.626964
# ...            ...          ...              ...
# Attr10      Attr10            0         0.000000
# Attr7        Attr7            0         0.000000
# Attr6        Attr6            0         0.000000
# Attr3        Attr3            0         0.000000
# class        class            0         0.000000
#
# [65 rows x 3 columns]

# %%
with pd.option_context('display.max_columns', None):
    display(df_pos.describe())
    display(df_neg.describe())
    display(df.describe())
# Out:
#             Attr1       Attr2       Attr3       Attr4        Attr5  \
# count  495.000000  495.000000  495.000000  494.000000   495.000000
# mean    -0.026058    1.647506   -0.894385    5.102372   -79.875680
# std      1.052486   20.066524   20.051634   48.314299   426.110098
# min     -9.743700    0.000000 -445.880000    0.002238 -4111.300000
# 25%     -0.078606    0.454405   -0.123695    0.791820   -90.081000
# 50%      0.004423    0.665220    0.062291    1.135850   -31.588000
# 75%      0.045752    0.858270    0.255400    1.679800     8.186450
# max     20.481000  446.880000    0.998910  916.500000  2586.500000
#
#             Attr6       Attr7       Attr8       Attr9      Attr10      Attr11  \
# count  495.000000  495.000000  494.000000  494.000000  495.000000  495.000000
# mean    -1.157958   -0.017876    3.937788    1.775757   -0.667160    0.007325
# std     21.884731    1.054317   42.413324    2.003631   20.064870    1.039911
# ...

# %% [markdown]
# ---
# ## Year 4

# %%
arff = loadarff(data_path+'4year.arff')
df = pd.DataFrame(arff[0])

# %%
df['class']= df['class'].astype('int')
df.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5     Attr6     Attr7    Attr8  \
# 0  0.159290  0.46240  0.07773  1.1683  -44.853  0.467020  0.189480  0.82895
# 1 -0.127430  0.46243  0.26917  1.7517    7.597  0.000925 -0.127430  1.16250
# 2  0.070488  0.23570  0.52781  3.2393  125.680  0.163670  0.086895  2.87180
# 3  0.136760  0.40538  0.31543  1.8705   19.115  0.504970  0.136760  1.45390
# 4 -0.110080  0.69793  0.18878  1.2713  -15.344  0.000000 -0.110080  0.43282
#
#     Attr9   Attr10  ...    Attr56   Attr57   Attr58    Attr59   Attr60  \
# 0  1.1223  0.38330  ...  0.108990  0.41557  0.89101  0.001422   7.7928
# 1  1.2944  0.53757  ... -0.089372 -0.23704  1.06250  0.150410   5.4327
# 2  1.0574  0.67689  ...  0.054286  0.10413  0.94571  0.000000   7.1070
# 3  1.1144  0.58938  ...  0.102630  0.23203  0.89737  0.073024   6.1384
# 4  1.7350  0.30207  ...  0.439880 -0.36440  0.57153  0.000000  18.8010
#
#    Attr61   Attr62  Attr63   Attr64  class
# ...

# %%
df['class'].value_counts()
# Out:
# 0    9277
# 1     515
# Name: class, dtype: int64

# %%
df_pos = df[df['class']==1]
df_neg = df[df['class']==0]

# %%
percent_missing = df_pos.isnull().sum()
percent_missing_p = percent_missing / df_pos.shape[0] * 100.00
missing_value_df = pd.DataFrame({'column_name': df_pos.columns,
                                 'num_missing': percent_missing,
                                 'percent_missing': percent_missing_p})
missing_value_df.sort_values('percent_missing', inplace=True, ascending=False)
missing_value_df
# Out:
#        column_name  num_missing  percent_missing
# Attr37      Attr37          259        50.291262
# Attr27      Attr27          154        29.902913
# Attr21      Attr21          113        21.941748
# Attr60      Attr60           53        10.291262
# Attr45      Attr45           53        10.291262
# ...            ...          ...              ...
# Attr29      Attr29            0         0.000000
# Attr2        Attr2            0         0.000000
# Attr34      Attr34            0         0.000000
# Attr35      Attr35            0         0.000000
# class        class            0         0.000000
#
# [65 rows x 3 columns]

# %%
percent_missing = df_neg.isnull().sum()
percent_missing_p = percent_missing / df_neg.shape[0] * 100.00
missing_value_df = pd.DataFrame({'column_name': df_neg.columns,
                                 'num_missing': percent_missing,
                                 'percent_missing': percent_missing_p})
missing_value_df.sort_values('percent_missing', inplace=True, ascending=False)
missing_value_df
# Out:
#        column_name  num_missing  percent_missing
# Attr37      Attr37         4183        45.090008
# Attr60      Attr60          561         6.047214
# Attr45      Attr45          560         6.036434
# Attr27      Attr27          487         5.249542
# Attr24      Attr24          211         2.274442
# ...            ...          ...              ...
# Attr55      Attr55            0         0.000000
# Attr57      Attr57            0         0.000000
# Attr59      Attr59            0         0.000000
# Attr9        Attr9            0         0.000000
# class        class            0         0.000000
#
# [65 rows x 3 columns]

# %%
percent_missing = df.isnull().sum()
percent_missing_p = percent_missing / df.shape[0] * 100.00
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'num_missing': percent_missing,
                                 'percent_missing': percent_missing_p})
missing_value_df.sort_values('percent_missing', inplace=True, ascending=False)
missing_value_df
# Out:
#        column_name  num_missing  percent_missing
# Attr37      Attr37         4442        45.363562
# Attr27      Attr27          641         6.546160
# Attr60      Attr60          614         6.270425
# Attr45      Attr45          613         6.260212
# Attr64      Attr64          231         2.359069
# ...            ...          ...              ...
# Attr2        Attr2            1         0.010212
# Attr35      Attr35            1         0.010212
# Attr55      Attr55            0         0.000000
# Attr9        Attr9            0         0.000000
# class        class            0         0.000000
#
# [65 rows x 3 columns]

# %%
with pd.option_context('display.max_columns', None):
    display(df_pos.describe())
    display(df_neg.describe())
    display(df.describe())
# Out:
#             Attr1       Attr2       Attr3       Attr4         Attr5  \
# count  515.000000  515.000000  515.000000  514.000000    515.000000
# mean    -0.068873    0.878355   -0.063312    3.788801    -87.175988
# std      0.568076    1.945596    0.908831   18.344093   1019.403433
# min     -4.050600    0.000357  -14.989000    0.002023 -10505.000000
# 25%     -0.145510    0.458885   -0.166430    0.736528   -102.805000
# 50%      0.000000    0.671030    0.030773    1.067950    -39.064000
# 75%      0.044640    0.882850    0.269595    1.655475      8.872200
# max      9.803700   40.157000    1.000000  214.440000   8197.100000
#
#             Attr6       Attr7        Attr8       Attr9      Attr10  \
# count  515.000000  515.000000   515.000000  515.000000  515.000000
# mean    -0.343200   -0.061538     8.749121    1.950155    0.103367
# std      2.354812    0.568432   125.160234    4.555089    1.946747
# min    -46.873000   -4.050600    -0.975060    0.000000  -39.156000
# ...

# %% [markdown]
# ---
# ## Year 5

# %%
arff = loadarff(data_path+'5year.arff')
df = pd.DataFrame(arff[0])

# %%
df['class']= df['class'].astype('int')
df.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4     Attr5     Attr6     Attr7    Attr8  \
# 0  0.088238  0.55472  0.01134  1.0205  -66.5200  0.342040  0.109490  0.57752
# 1 -0.006202  0.48465  0.23298  1.5998    6.1825  0.000000 -0.006202  1.06340
# 2  0.130240  0.22142  0.57751  3.6082  120.0400  0.187640  0.162120  3.05900
# 3 -0.089951  0.88700  0.26927  1.5222  -55.9920 -0.073957 -0.089951  0.12740
# 4  0.048179  0.55041  0.10765  1.2437  -22.9590  0.000000  0.059280  0.81682
#
#     Attr9   Attr10  ...    Attr56    Attr57   Attr58    Attr59   Attr60  \
# 0  1.0881  0.32036  ...  0.080955  0.275430  0.91905  0.002024   7.2711
# 1  1.2757  0.51535  ... -0.028591 -0.012035  1.00470  0.152220   6.0911
# 2  1.1415  0.67731  ...  0.123960  0.192290  0.87604  0.000000   8.7934
# 3  1.2754  0.11300  ...  0.418840 -0.796020  0.59074  2.878700   7.6524
# 4  1.5150  0.44959  ...  0.240400  0.107160  0.77048  0.139380  10.1180
#
#    Attr61   Attr62  Attr63  Attr64  class
# ...

# %%
df['class'].value_counts()
# Out:
# 0    5500
# 1     410
# Name: class, dtype: int64

# %%
df_pos = df[df['class']==1]
df_neg = df[df['class']==0]

# %%
percent_missing = df_pos.isnull().sum()
percent_missing_p = percent_missing / df_pos.shape[0] * 100.00
missing_value_df = pd.DataFrame({'column_name': df_pos.columns,
                                 'num_missing': percent_missing,
                                 'percent_missing': percent_missing_p})
missing_value_df.sort_values('percent_missing', inplace=True, ascending=False)
missing_value_df
# Out:
#        column_name  num_missing  percent_missing
# Attr37      Attr37          210        51.219512
# Attr27      Attr27          123        30.000000
# Attr21      Attr21           99        24.146341
# Attr60      Attr60           38         9.268293
# Attr45      Attr45           38         9.268293
# ...            ...          ...              ...
# Attr42      Attr42            0         0.000000
# Attr41      Attr41            0         0.000000
# Attr39      Attr39            0         0.000000
# Attr23      Attr23            0         0.000000
# class        class            0         0.000000
#
# [65 rows x 3 columns]

# %%
percent_missing = df_neg.isnull().sum()
percent_missing_p = percent_missing / df_neg.shape[0] * 100.00
missing_value_df = pd.DataFrame({'column_name': df_neg.columns,
                                 'num_missing': percent_missing,
                                 'percent_missing': percent_missing_p})
missing_value_df.sort_values('percent_missing', inplace=True, ascending=False)
missing_value_df
# Out:
#        column_name  num_missing  percent_missing
# Attr37      Attr37         2338        42.509091
# Attr27      Attr27          268         4.872727
# Attr45      Attr45          230         4.181818
# Attr60      Attr60          230         4.181818
# Attr24      Attr24          134         2.436364
# ...            ...          ...              ...
# Attr42      Attr42            0         0.000000
# Attr30      Attr30            0         0.000000
# Attr31      Attr31            0         0.000000
# Attr39      Attr39            0         0.000000
# class        class            0         0.000000
#
# [65 rows x 3 columns]

# %%
percent_missing = df.isnull().sum()
percent_missing_p = percent_missing / df.shape[0] * 100.00
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'num_missing': percent_missing,
                                 'percent_missing': percent_missing_p})
missing_value_df.sort_values('percent_missing', inplace=True, ascending=False)
missing_value_df
# Out:
#        column_name  num_missing  percent_missing
# Attr37      Attr37         2548        43.113367
# Attr27      Attr27          391         6.615905
# Attr45      Attr45          268         4.534687
# Attr60      Attr60          268         4.534687
# Attr24      Attr24          135         2.284264
# ...            ...          ...              ...
# Attr42      Attr42            0         0.000000
# Attr30      Attr30            0         0.000000
# Attr31      Attr31            0         0.000000
# Attr39      Attr39            0         0.000000
# class        class            0         0.000000
#
# [65 rows x 3 columns]

# %%
with pd.option_context('display.max_columns', None):
    display(df_pos.describe())
    display(df_neg.describe())
    display(df.describe())
# Out:
#             Attr1       Attr2       Attr3       Attr4         Attr5  \
# count  409.000000  409.000000  409.000000  407.000000  4.100000e+02
# mean    -1.354743    1.216161   -0.381965    4.561006 -2.753233e+03
# std     22.988144    4.290112    3.687481   29.391724  5.315934e+04
# min   -463.890000    0.000000  -72.067000   -0.403110 -1.076400e+06
# 25%     -0.234020    0.476590   -0.302450    0.555040 -1.332900e+02
# 50%     -0.066961    0.724760   -0.011561    0.965840 -5.671350e+01
# 75%      0.023165    0.975650    0.238260    1.519700 -9.627950e-01
# max      5.530000   72.416000    1.000000  477.160000  5.091200e+03
#
#             Attr6       Attr7       Attr8       Attr9      Attr10      Attr11  \
# count  409.000000  409.000000  407.000000  410.000000  409.000000  409.000000
# mean    -1.720120   -1.349486    4.102053    1.814958    0.411395   -1.313553
# std     23.151473   22.988739   30.553457    1.861876   13.886668   22.990921
# ...
