# %% [markdown]
# ### Importing Libraries

# %%
import os
from scipy.io import arff
import pandas as pd
import numpy as np

# %% [markdown]
# ### Loading files

# %%
path_to_directory= r"D:\mtl782_project\\"
files = [arff for arff in os.listdir(path_to_directory) if arff.endswith(".arff")]
print(files)
# Out:
# ['1year.arff', '2year.arff', '3year.arff', '4year.arff', '5year.arff']

# %%
df1 = arff.loadarff(r"D:\mtl782_project\\1year.arff")
data1 = pd.DataFrame(df1[0])
df2 = arff.loadarff(r"D:\mtl782_project\\2year.arff")
data2 = pd.DataFrame(df2[0])
df3 = arff.loadarff(r"D:\mtl782_project\\3year.arff")
data3 = pd.DataFrame(df3[0])
df4 = arff.loadarff(r"D:\mtl782_project\\4year.arff")
data4 = pd.DataFrame(df4[0])
df5 = arff.loadarff(r"D:\mtl782_project\\5year.arff")
data5 = pd.DataFrame(df5[0])

# %%
data1.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7    Attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     Attr9   Attr10  ...    Attr56   Attr57   Attr58    Attr59  Attr60  Attr61  \
# 0  1.1389  0.50494  ...  0.121960  0.39718  0.87804  0.001924  8.4160  5.1372
# 1  1.6996  0.49788  ...  0.121300  0.42002  0.85300  0.000000  4.1486  3.2732
# 2  1.3090  0.30408  ...  0.241140  0.81774  0.76599  0.694840  4.9909  3.9510
# 3  1.0571  0.57353  ...  0.054015  0.14207  0.94598  0.000000  4.5746  3.6147
# 4  1.1559  0.38677  ...  0.134850  0.48431  0.86515  0.124440  6.3985  4.3158
#
#     Attr62  Attr63   Attr64  class
# ...

# %%
data1.describe()
# Out:
#              Attr1        Attr2        Attr3        Attr4         Attr5  \
# count  7024.000000  7024.000000  7024.000000  6997.000000  7.019000e+03
# mean      0.034660     0.560215     0.119969     2.629143 -2.631672e+02
# std       4.565504     5.350084     5.275459    13.257356  3.707460e+04
# min    -256.890000   -72.162000  -440.500000     0.000000 -2.722100e+06
# 25%       0.021182     0.296678     0.026968     1.063100 -4.449800e+01
# 50%       0.075802     0.482960     0.181275     1.502000 -5.373900e+00
# 75%       0.160268     0.680233     0.362548     2.460700  3.777050e+01
# max      94.280000   441.500000     1.000000  1017.800000  9.909000e+05
#
#              Attr6        Attr7        Attr8        Attr9       Attr10  ...  \
# count  7024.000000  7024.000000  7002.000000  7026.000000  7024.000000  ...
# mean      0.059712     0.313876     2.623996     5.552855     1.825832  ...
# std       6.051113     8.353274    18.708327   101.995448    33.836452  ...
# ...

# %%
data1.shape
# Out:
# (7027, 65)

# %%
for i in range(64):
    name = "Attr" + str(i+1)
    data1[name] = pd.to_numeric(data1[name], errors='coerce', downcast = "float")
    data2[name] = pd.to_numeric(data2[name], errors='coerce', downcast = "float")
    data3[name] = pd.to_numeric(data3[name], errors='coerce', downcast = "float")
    data4[name] = pd.to_numeric(data4[name], errors='coerce', downcast = "float")
    data5[name] = pd.to_numeric(data5[name], errors='coerce', downcast = "float")

# %% [markdown]
# ## Replacing NA with Mean

# %%
for i in range(64):
    name = "Attr" + str(i+1)   
    data1[name] = data1[name].fillna(value= data1[name].mean())
    data2[name] = data2[name].fillna(value= data2[name].mean())
    data3[name] = data3[name].fillna(value= data3[name].mean())
    data4[name] = data4[name].fillna(value= data4[name].mean())
    data5[name] = data5[name].fillna(value= data5[name].mean())

# %%
X1,y1 = data1.iloc[:,:-1], data1.iloc[:,-1]
X2,y2 = data2.iloc[:,:-1], data2.iloc[:,-1]
X3,y3 = data3.iloc[:,:-1], data3.iloc[:,-1]
X4,y4 = data4.iloc[:,:-1], data4.iloc[:,-1]
X5,y5 = data5.iloc[:,:-1], data5.iloc[:,-1]

# %%
y1=y1.astype('int')
y2=y2.astype('int')
y3=y3.astype('int')
y4=y4.astype('int')
y5=y5.astype('int')

# %% [markdown]
# ### Feature Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
import seaborn as sns

# %%
model = ExtraTreesClassifier()

model.fit(X1,y1)
feat_importances = pd.Series(model.feature_importances_, index=X1.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.title("1 Year")
plt.show()

model.fit(X2,y2)
feat_importances = pd.Series(model.feature_importances_, index=X2.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.title("2 Year")
plt.show()

model.fit(X3,y3)
feat_importances = pd.Series(model.feature_importances_, index=X3.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.title("3 Year")
plt.show()

model.fit(X4,y4)
feat_importances = pd.Series(model.feature_importances_, index=X4.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.title("4 Year")
plt.show()

model.fit(X5,y5)
feat_importances = pd.Series(model.feature_importances_, index=X5.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.title("5 Year")
plt.show()



#print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization

# %% [markdown]
# ### Correlation Matrix

# %%
corrmat1 = data1.corr()
top_corr_features1 = corrmat1.index
plt.figure(figsize=(60,60))
plt.title("1 year")
g1 = sns.heatmap(data1[top_corr_features1].corr(),annot=False ,cmap="RdYlGn")

corrmat2 = data2.corr()
top_corr_features2 = corrmat2.index
plt.figure(figsize=(60,60))
plt.title("2 year")
g2 = sns.heatmap(data2[top_corr_features2].corr(),annot=False ,cmap="RdYlGn")

corrmat3 = data3.corr()
top_corr_features3 = corrmat3.index
plt.figure(figsize=(60,60))
plt.title("3 year")
g3 = sns.heatmap(data3[top_corr_features3].corr(),annot=False ,cmap="RdYlGn")

corrmat4 = data4.corr()
top_corr_features4 = corrmat4.index
plt.figure(figsize=(60,60))
plt.title("4 year")
g4 = sns.heatmap(data4[top_corr_features4].corr(),annot=False ,cmap="RdYlGn")

corrmat5 = data5.corr()
top_corr_features5 = corrmat5.index
plt.figure(figsize=(60,60))
plt.title("5 year")
g5 = sns.heatmap(data5[top_corr_features5].corr(),annot=False ,cmap="RdYlGn")
